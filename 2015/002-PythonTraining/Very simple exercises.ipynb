# %%
assert max(1,2) == 2
assert max_of_three(2,1,3) == 3

assert vokal('x')==False
assert vokal('a')==True
assert vokal('e')==True

assert robber('this is fun') == 'tothohisos issos fofunon'
assert sum([1,2,3,4]) == 10
assert mult([1,2,3,4]) == 24

# %%
a = 'harald'

assert len(a) == 6
assert a[0]=='h'
assert a[-1]=='d'
assert a[1:3] == 'ar'
assert a[0:6:2] == 'hrl'
assert a[::-1] == 'dlarah'
assert sorted(a) == ['a', 'a', 'd', 'h', 'l', 'r']
assert a + a == 'haraldharald'
assert 2 * a == 'haraldharald'

assert a.capitalize() == 'Harald'
assert a.count('a') == 2
assert a.startswith('h') == True
assert a.endswith('ld') 
assert a.index('a') == 1
assert a.rindex('a') == 3
lst = ['adam','bertil']
assert ' '.join(lst) == 'adam bertil'
assert a.replace('a','*') == 'h*r*ld'
assert 'adam bertil'.split(' ') == ['adam','bertil'] 
assert ' ivar '.strip() == 'ivar'
assert a.upper() == 'HARALD'

# Övningar

f = lambda x: x.capitalize()
g = lambda x: x.upper()
h = lambda x: x[2]
i = lambda x: x[2:4]
j = lambda x: x[::-1]
k = lambda x: x.split('i')
l = lambda x,y,z: x.replace(y,z)
m = lambda x: x[::-1].replace('*','i')
n = lambda x: '-'.join(sorted(x))
o = lambda x: x + '|' + x[::-1]

assert f('pelle') == 'Pelle'
assert g('pelle') == 'PELLE'
assert h('viktor') == 'k'
assert i('viktor') == 'kt'
assert j('rotkiv') == 'viktor'
assert k('christer nilsson') == ['chr','ster n','lsson']
assert l('christer nilsson','i','#') == 'chr#ster n#lsson'
assert m('nossl*n rets*rhc') == 'christer nilsson'
assert n('christer') == 'c-e-h-i-r-r-s-t'
assert o('ivar') == 'ivar|ravi'

# %%
a = []
a.append(10)
assert a == [10]
a.append(11)
assert a == [10,11]
assert a[1] == 11
a[0] = 9
assert a == [9,11]
a.insert(1,10)
assert a == [9,10,11]
del a[1]
assert a == [9,11]
assert len(a) == 2
a.append(11)
assert a == [9,11,11]
assert a.count(11) == 2
assert a.index(11) == 1
b = a.pop()
assert b == 11
assert a == [9,11]
a.remove(9)
assert a == [11]
a.extend([9,10])
assert a == [11,9,10]
assert a[::-1] == [10,9,11]
assert sorted(a) == [9,10,11]
assert 2*a == [11,9,10,11,9,10]
assert a+a == [11,9,10,11,9,10]

f = lambda x : sorted(x)
g = lambda x : x[::-1]
h = lambda x : x + x[::-1]
i = lambda x : sorted(x + x)[::-1]
j = lambda x : [1] + x
k = lambda x : x + [5]

a = [3,2,4]
assert f(a) == [2,3,4]
assert g(a) == [4,2,3]
assert h(a) == [3,2,4,4,2,3]
assert i(a) == [4,4,3,3,2,2]
assert j(a) == [1,3,2,4]
assert k(a) == [3,2,4,5]
assert a == [3,2,4]

# %%
a = {}
a['name'] = 'Harald'
assert a == {'name': 'Harald'}
a['year'] = 2007
assert a == {'name': 'Harald','year': 2007}
assert len(a) == 2
assert a.keys() == ['name','year']
assert a.values() == ['Harald',2007]
a.clear()
assert a == {}
b = {'name':'Jenny', 'kids': ['Viktor','Ivar','Harald']}
assert b['kids'] == ['Viktor','Ivar','Harald']
del b['kids'] 
assert b == {'name':'Jenny'}

f = lambda x: len(x)
g = lambda x: x['name']
h = lambda x: x['kids']
i = lambda x: len(x['kids'])
j = lambda x: x.keys()
k = lambda x: x.values()


b = {'name':'Jenny', 'kids': ['Viktor','Ivar','Harald']}
assert f(b) == 2
assert g(b) == 'Jenny'
assert h(b) == ['Viktor','Ivar','Harald']
assert i(b) == 3
assert j(b) == ['kids', 'name']
assert k(b) == [['Viktor','Ivar','Harald'],'Jenny']

# %%
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__class__',
#  '__cmp__',
#  '__coerce__',
#  '__delattr__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__hash__',
#  '__hex__',
#  '__index__',
#  '__init__',
#  '__int__',
#  '__invert__',
#  '__long__',
#  '__lshift__',
#  '__mod__',
#  '__mul__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__oct__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'imag',
# ...
